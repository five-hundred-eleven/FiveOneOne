# %%
# !pip install -i https://test.pypi.org/simple/ five-one-one==0.2.2
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting five-one-one==0.2.2
#   Downloading https://test-files.pythonhosted.org/packages/3e/bb/1a41ca30921335c21fbf1d33fcc9d685ddc2abc55f6c5868f92f5b9671f8/five_one_one-0.2.2-py3-none-any.whl
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (from five-one-one==0.2.2) (2.1.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from five-one-one==0.2.2) (1.17.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from five-one-one==0.2.2) (0.25.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (0.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (2.21.0)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (0.2.4)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (0.9.6)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (1.0.1)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (7.0.8)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (2.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy->five-one-one==0.2.2) (2.0.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->five-one-one==0.2.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->five-one-one==0.2.2) (2.6.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->five-one-one==0.2.2) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->five-one-one==0.2.2) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->five-one-one==0.2.2) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy->five-one-one==0.2.2) (1.24.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.1.0,>=7.0.8->spacy->five-one-one==0.2.2) (4.28.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->five-one-one==0.2.2) (1.12.0)
# Installing collected packages: five-one-one
# Successfully installed five-one-one-0.2.2

# %%
import FiveOneOne

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/voting-records/house-votes-84.data
# Out:
# --2020-02-14 01:51:36--  https://archive.ics.uci.edu/ml/machine-learning-databases/voting-records/house-votes-84.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18171 (18K) [application/x-httpd-php]
# Saving to: ‘house-votes-84.data’
#
# house-votes-84.data 100%[===================>]  17.75K  --.-KB/s    in 0.03s
#
# 2020-02-14 01:51:36 (605 KB/s) - ‘house-votes-84.data’ saved [18171/18171]

# %%
import pandas as pd

column_headers = ['party','handicapped-infants','water-project',
                          'budget','physician-fee-freeze', 'el-salvador-aid',
                          'religious-groups','anti-satellite-ban',
                          'aid-to-contras','mx-missile','immigration',
                          'synfuels', 'education', 'right-to-sue','crime','duty-free',
                          'south-africa']
df = pd.read_csv("house-votes-84.data", header=None, names=column_headers)

df.head()
# Out:
#         party handicapped-infants water-project  ... crime duty-free south-africa
# 0  republican                   n             y  ...     y         n            y
# 1  republican                   n             y  ...     y         n            ?
# 2    democrat                   ?             y  ...     y         n            n
# 3    democrat                   n             y  ...     n         n            y
# 4    democrat                   y             y  ...     y         y            y
#
# [5 rows x 17 columns]

# %%
dems = df[df["party"] == "democrat"]
reps = df[df["party"] == "republican"]

# %%
from FiveOneOne.df_utils import train_validate_test_split, confidenceInterval, bayesConfidenceInterval

# %%
train, val, test = train_validate_test_split(df)

# %%
train.shape, val.shape, test.shape
# Out:
# ((261, 17), (87, 17), (87, 17))

# %%
df = df.replace({"n": 0, "y": 1})

# %%
dems = dems.drop(columns=["party"])
dems = dems.replace({"n": -1, "?": 0, "y": 1})

# %%
confidenceInterval(dems["budget"])
# Out:
# (0.680068480081707, 0.7565543071161048, 0.8330401341505027)

# %%
confidenceInterval.__doc__
# Out:
# '\n        Returns the confidence interval and mean for the data within the given\n        {confidence}.\n\n        @type data: DataFrame\n        @type confidence: float\n\n        @returns: tuple of 3 floats representing the left confidence interval,\n            the median, and the right confidence interval for the data.\n    '

# %%
help(confidenceInterval)
# Out:
# Help on function confidenceInterval in module FiveOneOne.df_utils:
#
# confidenceInterval(data, confidence=0.95)
#     Returns the confidence interval and mean for the data within the given
#     {confidence}.
#
#     @type data: DataFrame
#     @type confidence: float
#
#     @returns: tuple of 3 floats representing the left confidence interval,
#         the median, and the right confidence interval for the data.

# %%
from FiveOneOne.df_utils import ColumnCompare

reps = reps.drop(columns=["party"])
reps = reps.replace({"n": -1, "?": 0, "y": 1})

# %%
cc = ColumnCompare(dems, reps)

# %%
cc.test("budget")
# Out:
# Ttest_indResult(statistic=22.8216930438848, pvalue=2.8721153143958906e-76)

# %%
cc.test("water-project")
# Out:
# Ttest_indResult(statistic=-0.08764559884421932, pvalue=0.9301988772663677)

# %%
pd.options.display.max_rows = 999

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

##### Your Code Here #####
df = pd.read_csv("https://github.com/ekoly/DS-Unit-4-Sprint-1-NLP/raw/master/module2-vector-representations/data/job_listings.csv")
df.head()

df["description"] = df["description"].apply(lambda s: " ".join(BeautifulSoup(s, "html.parser").stripped_strings).replace("\\n", " "))
df.head()

from FiveOneOne import nlp_utils

# %%
df["description"].apply(nlp_utils.simple_tokenize)
# Out:
# 0      [b, job, requirements, conceptual, understand,...
# 1      [b, job, description, data, scientist, 1, help...
# 2      [b, data, scientist, work, consult, business, ...
# 3      [b, 4969, 6756, month, contract, general, supe...
# 4      [b, location, usa, xe2x80x93, multiple, locati...
# 5      [b, create, business, intelligence, analytical...
# 6      [b, spotify, premium, swell, 96m, subscriber, ...
# 7      [beverytown, gun, safety, nations, large, gun,...
# 8      [b, ms, quantitative, discipline, statistics, ...
# 9      [b, slack, hire, experience, datum, scientist,...
# 10     [b, blackthorn, therapeutics, computational, s...
# 11     [b, parttime, opportunity, grubhub, wexe2x80x9...
# 12     [bnfosysxe2x80x93, data, analytics, xe2x80x93,...
# 13     [b, spotify, premium, swell, 96m, subscriber, ...
# 14     [b, experience, guide, rd, strategy, organizat...
# 15     [b, atlantic, seek, data, scientist, help, lea...
# 16     [b, challenge, eventbrite, big, bustle, market...
# 17     [b, contract, look, hire, data, scientist, rem...
# 18     [beverytown, gun, safety, nations, large, gun,...
# 19     [b, 70000, 100000, year, title, data, analystj...
# 20     [b, 45000, year, working, direction, associate...
# 21     [b, challenge, excite, prospect, unlock, secre...
# 22     [b, seek, data, scientist, join, product, insi...
# 23     [b, motiion, technology, datum, company, food,...
# 24     [b, scientist, responsible, scientific, integr...
# 25     [bas, data, scientist, ads, measurement, partn...
# 26     [b, summary, posted, mar, 6, 2019, weekly, hou...
# 27     [b, slack, look, experience, datum, scientist,...
# 28     [bnfosysxe2x80x93, data, analytics, xe2x80x93,...
# 29     [b, parttime, internship, summary, sierra, nev...
# 30     [b, internship, overview, day, perspecta, enab...
# 31     [b, wexe2x80x99re, look, data, scientist, grow...
# 32     [b, jr, data, scientist, share, find, similar,...
# 33     [b, degree, computer, science, engineering, ma...
# 34     [bevery, day, passionate, employee, connect, c...
# 35     [b, temporary, internship, mongodb, seek, high...
# 36     [b, position, summary, todayxe2x80x99s, fast, ...
# 37     [b, temporary, internship, position, descripti...
# 38     [b, temporary, internship, responsibilities, p...
# 39     [b, 138579, year, collects, analyze, statistic...
# 40     [b, temporary, internship, job, description, s...
# 41     [b, inscape, an, affiliate, vizio, inc, indust...
# 42     [b, job, description, 510, year, handson, expe...
# 43     [b, blackthorn, therapeutics, computational, s...
# 44     [b, 200000, 350000, year, million, people, yea...
# 45     [b, collaborate, bright, technical, mind, buil...
# 46     [b, data, scientist, verb, surgical, google, j...
# 47     [b, description, rare, opportunity, join, deve...
# 48     [b, parttime, temporary, internship, bmw, tech...
# 49     [b, position, purpose, primary, purpose, posit...
# 50     [b, data, scientist, multiple, levels19000c1k,...
# 51     [budacitys, mission, democratize, education, w...
# 52     [b, challenge, adobe, look, senior, data, scie...
# 53     [b, temporary, internship, c3, lead, enterpris...
# 54     [b, uber, ignite, opportunity, set, world, mot...
# 55     [b, senior, data, scientist19000bn4, preferred...
# 56     [b, temporary, internship, description, data, ...
# 57     [b, 67968, 126062, year, data, scientist, cia,...
# 58     [b, temporary, internship, rifiniti, growthsta...
# 59     [b, internship, youll, doing, data, scientist,...
# 60     [b, requisition, id, req6316, job, title, data...
# 61     [b, data, scientist, 2190007ji, preferred, qua...
# 62     [b, business, unit, introduction, position, en...
# 63     [b, 40, 42, hour, parttime, contractor, positi...
# 64     [b, uber, ignite, opportunity, set, world, mot...
# 65     [b, note, apply, position, application, automa...
# 66     [b, slack, look, experience, datum, scientist,...
# 67     [b, internship, criteo, connect, 15, billion, ...
# 68     [bthis, excite, fulltime, opportunity, work, f...
# 69     [b, junior, data, scientist, big, data, entryl...
# 70     [b, junior, data, scientist, big, data, entryl...
# 71     [b, data, scientist, responsible, model, compl...
# 72     [b, responsibilities, include, supportdevelop,...
# 73     [bdescription, nyc, innovation, team, locate, ...
# 74     [b, 62844, 100908, year, summary, us, oregon, ...
# 75     [b, title, data, scientist, job, location, col...
# 76     [b, title, data, scientist, role, design, peop...
# 77     [b, uber, wexe2x80x99re, change, way, people, ...
# 78     [b, 2193, 2643, hour, internship, data, scient...
# 79     [b, contract, akraya, look, data, scientist, c...
# 80     [b, contract, data, engineer, key, technical, ...
# 81     [b, clinical, data, scientist, job, locations,...
# 82     [bfounded, 2015, honor, fastestgrowing, nonmed...
# 83     [bcompany, projectmanagercom, awardwinning, pr...
# 84     [b, internship, data, scientist, intern, inter...
# 85     [b, temporary, internship, job, description, s...
# 86     [b, position, description, demonstrates, uptod...
# 87     [b, contract, transformational, partner, marry...
# 88     [b, position, description, walmart, voice, com...
# 89     [b, uber, wexe2x80x99re, change, way, people, ...
# 90     [b, data, scientist, multiple, levels19000c1k,...
# 91     [b, atos, se, societas, europaea, leader, digi...
# 92     [b, come, work, us, look, dedicate, employee, ...
# 93     [b, major, responsibilities, researches, ident...
# 94     [b, westrock, westrock, nyse, wrk, partner, cu...
# 95     [b, slack, hire, experience, datum, scientist,...
# 96     [b, internship, position, description, add, te...
# 97     [bwere, look, data, scientists, passionate, ge...
# 98     [b, uber, ignite, opportunity, set, world, mot...
# 99     [b, associate, statistical, modeler, conduct, ...
# 100    [b, description, rare, opportunity, join, deve...
# 101    [b, united, states, strategic, command, usstra...
# 102    [babout, company, civis, analytics, technology...
# 103    [bcustomer, facing, data, scientists, cfdss, c...
# 104    [b, internship, its, fun, work, company, peopl...
# 105    [b, data, scientist, duty, typically, focus, c...
# 106    [b, look, senior, level, datum, scientist, 6, ...
# 107    [b, hrs, look, add, data, scientist, rapidly, ...
# 108    [bposition, kayak, look, people, love, work, d...
# 109    [b, position, description, product, catalog, t...
# 110    [binvitae, envision, world, genomic, sequence,...
# 111    [bmine, rich, user, datum, set, find, insight,...
# 112    [bwere, look, data, scientists, passionate, ge...
# 113    [b, xe2x80x9cpeople, personify, drive, exceed,...
# 114    [b, arthur, lawrence, urgently, look, data, sc...
# 115    [b, company, overview, proofpoint, passion, pr...
# 116    [b, 57000, 85000, year, georgia, policy, labs,...
# 117    [b, company, details, founded, 1967, w, r, ber...
# 118    [b, overview, based, northern, va, axiologic, ...
# 119    [b, data, scientist, role, instrumental, help,...
# 120    [b, description, position, background, know, s...
# 121    [b, parttime, nittany, artificial, intelligenc...
# 122    [b, senior, data, scientist19000bn4, preferred...
# 123    [b, motiion, technology, datum, company, food,...
# 124    [b, keysight, marketing, hire, datum, scientis...
# 125    [b, parttime, temporary, internship, bmw, tech...
# 126    [b, job, description, data, scientist, positio...
# 127    [b, null, associate, data, scientist, xe2x80x9...
# 128    [b, uber, ignite, opportunity, set, world, mot...
# 129    [b, trilogy, powered, big, dream, small, egos,...
# 130    [bwho, fullstack, datum, scientist, experience...
# 131    [b, slack, look, experience, datum, scientist,...
# 132    [binvitae, envision, world, genomic, sequence,...
# 133    [b, youxe2x80x99ll, work, huge, insurance, fir...
# 134    [b, 82000, year, innovation, center, clearwate...
# 135    [bparadigm, strategy, firm, partner, innovativ...
# 136    [b, were, waitr, were, redefine, dine, experie...
# 137    [b, wexe2x80x99re, elliott, davis, rapidly, gr...
# 138    [b, job, description, 510, year, handson, expe...
# 139    [b, looking, big, impact, revolutionize, front...
# 140    [bonly, local, candidate, consider, role, are,...
# 141    [b, role, babylist, look, data, analyst, join,...
# 142    [b, challenge, adobe, look, senior, data, scie...
# 143    [b, date, mar, 19, 2019, ericsson, overview, e...
# 144    [b, position, description, we, smart, pricing,...
# 145    [bfiat, chrysler, automobiles, look, fill, ful...
# 146    [b, temporary, internship, position, descripti...
# 147    [b, overview, responsibilities, role, join, ex...
# 148    [b, data, scientist, redjack, growing, protect...
# 149    [b, 2717, 3660, hour, data, scientist, graduat...
# 150    [b, contract, 1, year, contract, data, scienti...
# 151    [b, data, scientist, critical, position, dss, ...
# 152    [b, armour, choose, brand, generation, athlete...
# 153    [b, principal, data, scientist, responsible, l...
# 154    [b, job, description, tasks, reports, bat, arc...
# 155    [b, role, wework, datum, sit, center, business...
# 156    [b, inscape, an, affiliate, vizio, inc, indust...
# 157    [b, channel, intellectual, property, protectio...
# 158    [b, bachelor, masters, degree, highly, quantit...
# 159    [bexperiment, engineer, expect, help, define, ...
# 160    [b, core, challenge, come, intersect, grow, in...
# 161    [b, seek, manager, business, intelligence, bi,...
# 162    [b, team, data, science, team, newly, form, ap...
# 163    [b, position, embed, data, analytics, practice...
# 164    [b, position, description, look, experience, d...
# 165    [bthe, company, cross, well, silicon, valley, ...
# 166    [b, spin, spin, operate, electric, scooter, ci...
# 167    [b, clinical, data, scientist, job, locations,...
# 168    [b, logistics, differently, xpo, logistics, in...
# 169    [babout, role, analytics, work, numerous, depa...
# 170    [b, database, engineer, secret, work, youxe2x8...
# 171    [b, atlantic, seek, data, scientist, help, lea...
# 172    [b, title, data, scientist, role, design, peop...
# 173    [b, hire, remote, data, scientist, strong, mac...
# 174    [b, job, description, data, scientist, positio...
# 175    [bwere, look, data, scientists, passionate, ge...
# 176    [babout, company, civis, analytics, help, lead...
# 177    [b, data, scientist, role, instrumental, help,...
# 178    [b, rsg, seek, experience, data, scientist, jo...
# 179    [b, believe, great, write, experience, fast, o...
# 180    [b, contract, 6, month, contract, hire, positi...
# 181    [b, parttime, opportunity, grubhub, wexe2x80x9...
# 182    [b, scoop, scoop, bring, coworker, neighbor, e...
# 183    [b, channel, intellectual, property, protectio...
# 184    [b, overview, responsibilities, role, join, ex...
# 185    [b, fulltime, position, senior, data, scientis...
# 186    [b, position, description, demonstrates, uptod...
# 187    [b, internship, its, fun, work, company, peopl...
# 188    [b, conducts, research, advance, statistical, ...
# 189    [b, parttime, qxbranch, seek, talented, datum,...
# 190    [b, overview, day, life, data, scientist, prim...
# 191    [b, uber, ignite, opportunity, set, world, mot...
# 192    [b, internship, position, description, candida...
# 193    [b, internship, current, footprint, constructi...
# 194    [b, data, scientist, evaluate, improve, appzen...
# 195    [b, internship, advanced, analytics, organizat...
# 196    [b, temporary, internship, overview, getting, ...
# 197    [b, reonomy, leverage, power, datum, technolog...
# 198    [b, sr, data, scientist1901744, description, s...
# 199    [b, data, science, analytics, practice, group,...
# 200    [b, team, zillow, look, extraordinary, data, s...
# 201    [b, internship, overview, data, science, inter...
# 202    [b, contract, data, engineer, key, technical, ...
# 203    [b, proficiency, synthesize, interpret, data, ...
# 204    [b, internship, greater, new, york, mutual, in...
# 205    [b, sr, data, scientist1901744, description, s...
# 206    [bopenx, seek, data, scientist, responsible, e...
# 207    [b, 100000, 125000, year, description, chesape...
# 208    [b, applied, materials, leader, material, engi...
# 209    [babout, stanza, hundreds, million, pageviews,...
# 210    [b, temporary, internship, position, descripti...
# 211    [b, commission, red, hat, connect, innovative,...
# 212    [b, internship, job, description, smart, compa...
# 213    [b, houston, methodist, hm, look, passionate, ...
# 214    [b, uber, wexe2x80x99re, change, way, people, ...
# 215    [bcompany, profile, morgan, stanley, lead, glo...
# 216    [b, overview, newwave, information, technology...
# 217    [b, senior, business, intelligence, data, engi...
# 218    [b, primary, role, build, analytic, model, sup...
# 219    [b, auto, req, id, 169334br, job, description,...
# 220    [b, 78600, year, job, description, data, analy...
# 221    [b, uber, ignite, opportunity, set, world, mot...
# 222    [b, overview, 1strategy, awsonly, consultancy,...
# 223    [b, uber, ignite, opportunity, set, world, mot...
# 224    [b, grainger, broad, line, businesstobusiness,...
# 225    [b, mclean, 1, 19050, united, states, america,...
# 226    [b, contract, job, description, title, data, s...
# 227    [b, agency, job, overview, omd, awardwinning, ...
# 228    [b, internship, role, data, scientist, interns...
# 229    [b, expedia, wish, opportunity, transform, vol...
# 230    [b, spotify, seek, data, scientist, advanced, ...
# 231    [b, position, overview, oil, gas, division, cu...
# 232    [b, functional, description, designs, develop,...
# 233    [b, position, summary, general, direction, dat...
# 234    [b, nauvera, inc, look, entrepreneurial, data,...
# 235    [b, data, scientist, email, hrdataxpandercom, ...
# 236    [b, conducts, research, advance, statistical, ...
# 237    [b, microsoft, envision, world, passionate, in...
# 238    [babout, company, eyeview, video, market, tech...
# 239    [b, story, ulta, beauty, large, specialty, bea...
# 240    [b, minimum, qualifications, masters, degree, ...
# 241    [b, internship, job, description, global, chie...
# 242    [b, 40, 42, hour, parttime, contractor, positi...
# 243    [babout, company, civis, analytics, technology...
# 244    [b, zeus, flawless, stays, founded, november, ...
# 245    [b, responsibilities, development, predictive,...
# 246    [b, sourcing, analyst, jc, penney, company, in...
# 247    [b, position, description, need, phd, computer...
# 248    [b, job, description, outstanding, career, opp...
# 249    [bcompany, overview, digital, assets, data, le...
# 250    [b, lmi, seek, datadriven, highly, analytic, m...
# 251    [b, talent, acquisition, , powered, leapros, c...
# 252    [b, internship, position, description, candida...
# 253    [b, ascensus, fast, grow, company, excellent, ...
# 254    [b, review, job, detail, below, excite, possib...
# 255    [b, us, blacksky, division, spaceflight, indus...
# 256    [b, role, summary, ccs, data, scientist, respo...
# 257    [b, uber, ignite, opportunity, set, world, mot...
# 258    [b, data, scientist, avp, 180008jq, zurich, no...
# 259    [b, hrs, look, add, data, scientist, rapidly, ...
# 260    [b, collaborate, bright, technical, mind, buil...
# 261    [b, data, science, engineer, mintel, futures, ...
# 262    [b, arvr, team, facebook, help, people, world,...
# 263    [b, trading, technologies, team, look, senior,...
# 264    [b, growth, look, build, advanced, research, a...
# 265    [bthe, communications, information, navigation...
# 266    [bposition, kayak, look, people, love, work, d...
# 267    [b, groupon, datum, drive, decisions, change, ...
# 268    [b, uber, ignite, opportunity, set, world, mot...
# 269    [bplaystation, isnt, best, place, play, xe2x80...
# 270    [b, uber, ignite, opportunity, set, world, mot...
# 271    [bpurpose, job, currently, seek, talented, dat...
# 272    [b, summary, posted, dec, 10, 2018, role, numb...
# 273    [b, join, team, recognize, leadership, innovat...
# 274    [b, general, description, assist, researcher, ...
# 275    [b, minimum, qualifications, masters, degree, ...
# 276    [b, facebooks, mission, people, power, build, ...
# 277    [b, purpose, overall, relevance, organization,...
# 278    [b, temporary, internship, job, description, i...
# 279    [b, summary, posted, dec, 10, 2018, role, numb...
# 280    [b, drybar, blow, spindry, bar, set, shake, be...
# 281    [b, whats, music, soundcloud, worldxe2x80x99s,...
# 282    [b, interest, radically, improve, security, mi...
# 283    [b, summary, posted, mar, 15, 2019, role, numb...
# 284    [b, socure, headquarter, nyc, leader, machine,...
# 285    [b, jornaya, jornaya, httpwwwjornayacom, belie...
# 286    [babout, blueshift, empower, lead, digital, br...
# 287    [bwho, are, sixleaf, lead, market, platform, p...
# 288    [b, data, scientist, work, autonomously, gener...
# 289    [b, blockchain, worlds, lead, software, platfo...
# 290    [b, internship, team, autodesk, san, francisco...
# 291    [b, grow, data, science, team, central, global...
# 292    [b, discover, reward, way, work, discover, fin...
# 293    [b, general, information, ref, 25256, employee...
# 294    [b, collaborate, bright, technical, mind, buil...
# 295    [b, doing, forescout, forefront, iot, security...
# 296    [b, position, description, look, experience, d...
# 297    [b, ecolabxe2x80x99s, energy, division, seek, ...
# 298    [bthe, data, scientist, perform, analysis, mod...
# 299    [b, company, allazohealth, location, new, york...
# 300    [b, look, experience, data, scientist, launch,...
# 301    [b, facebooks, mission, people, power, build, ...
# 302    [b, fullpower, technology, leader, cloudbased,...
# 303    [b, temporary, internship, rifiniti, growthsta...
# 304    [b, collaborate, bright, technical, mind, buil...
# 305    [b, therexe2x80x99s, lot, work, osmo, love, st...
# 306    [b, review, job, detail, below, radiant, solut...
# 307    [b, job, description, toomey, technologies, im...
# 308    [b, cleanchoice, energy, look, data, scientist...
# 309    [b, contract, job, description, youxe2x80x99ll...
# 310    [b, uber, ignite, opportunity, set, world, mot...
# 311    [b, company, appzen, deliver, worldxe2x80x99s,...
# 312    [b, 2193, 2643, hour, internship, data, scient...
# 313    [b, hinge, healthxe2x80x99s, mission, improve,...
# 314    [babout, team, role, stitch, fix, datum, scien...
# 315    [b, 100000, 125000, year, description, chesape...
# 316    [bnauto, ai, technology, company, thats, impro...
# 317    [b, 62844, 100908, year, summary, us, oregon, ...
# 318    [b, overview, position, responsible, aid, oper...
# 319    [b, wanted, missiondriven, professional, exper...
# 320    [b, team, responsible, place, ad, twitter, ser...
# 321    [b, join, team, recognize, leadership, innovat...
# 322    [b, uber, ignite, opportunity, set, world, mot...
# 323    [b, role, babylist, look, data, analyst, join,...
# 324    [b, customer, hundred, thousand, question, pro...
# 325    [b, sparkfund, energy, technology, subscriptio...
# 326    [b, associate, data, scientist, work, team, wr...
# 327    [b, youxe2x80x99re, ready, innovate, help, lea...
# 328    [b, independence, blue, cross, look, data, sci...
# 329    [b, company, overview, complex, ecosystem, bac...
# 330    [b, location, san, jose, outward, inc, outward...
# 331    [bposition, summary, look, passionate, detailo...
# 332    [b, job, code, rs0057, researcher, iii, humani...
# 333    [bat, yeti, believe, time, spend, outdoor, mat...
# 334    [b, minimum, qualifications, masters, degree, ...
# 335    [b, spin, spin, operate, electric, scooter, ci...
# 336    [bdiscover, business, insights, identify, oppo...
# 337    [bmode, company, build, analyst, datum, scient...
# 338    [bthe, fca, manufacturing, planning, control, ...
# 339    [bat, yeti, believe, time, spend, outdoor, mat...
# 340    [b, position, objective, provide, efficient, e...
# 341    [b, position, title, data, scientist, position...
# 342    [b, universal, parks, resortsxe2x84xa2, enjoy,...
# 343    [b, 2717, 3660, hour, data, scientist, graduat...
# 344    [b, reonomy, leverage, power, datum, technolog...
# 345    [b, small, business, backbone, american, econo...
# 346    [b, youxe2x80x99ll, doing, strategic, modeling...
# 347    [b, 120000, year, lrs, consulting, services, d...
# 348    [bplaystation, isnt, best, place, play, xe2x80...
# 349    [babout, careof, careof, takecareofcom, httpst...
# 350    [b, company, information, paccar, fortune, 500...
# 351    [b, youxe2x80x99ll, doing, position, drive, pr...
# 352    [bopenx, seek, data, scientist, responsible, e...
# 353    [b, equal, opportunity, employer, minorityfema...
# 354    [b, challenge, adobexe2x80x99s, creative, clou...
# 355    [b, 82000, year, innovation, center, clearwate...
# 356    [b, internship, overview, geek, data, love, an...
# 357    [b, position, objective, data, scientist, inte...
# 358    [b, youxe2x80x99ll, doingxe2x80xa6, primary, f...
# 359    [b, maximizing, potential, learn, organise, ce...
# 360    [briskiq, world, leader, attack, surface, mana...
# 361    [b, los, gatos, california, science, analytics...
# 362    [babout, team, stitch, fix, datum, science, te...
# 363    [bjyve, skillsasaservice, platform, match, ent...
# 364    [b, circleup, harness, power, machine, learn, ...
# 365    [b, come, work, us, look, dedicate, employee, ...
# 366    [b, data, science, encompass, computational, s...
# 367    [babout, slyncio, wwwslyncio, httpwwwslyncio, ...
# 368    [b, job, description, global, good, collaborat...
# 369    [b, job, description, data, scientist, square,...
# 370    [b, internship, business, find, provide, solut...
# 371    [bfounded, dr, priscilla, chan, mark, zuckerbe...
# 372    [b, vision, pricing, merchandising, analytics,...
# 373    [b, overview, based, northern, va, axiologic, ...
# 374    [b, mission, palo, alto, networksxc2xae, start...
# 375    [b, position, description, look, experience, d...
# 376    [b, snowflake, snowflake, grow, fast, wexe2x80...
# 377    [b, team, responsible, place, ad, twitter, ser...
# 378    [b, degree, computer, science, engineering, ma...
# 379    [bclassdojos, vision, create, modern, educatio...
# 380    [b, sr, advisor, data, science, company, descr...
# 381    [b, mission, palo, alto, networksxc2xae, start...
# 382    [b, data, scientist, job, description, amplion...
# 383    [b, overview, data, science, department, seek,...
# 384    [b, requirements, sql, eg, hive, postgresql, m...
# 385    [b, coursera, found, computer, science, profes...
# 386    [b, 165000, year, collects, analyze, statistic...
# 387    [bare, passionate, power, technology, build, c...
# 388    [bposition, summary, looking, opportunity, use...
# 389    [b, position, summary, general, direction, dat...
# 390    [b, skills, python, r, machine, learn, statist...
# 391    [b, only, candidate, infectious, disease, mode...
# 392    [b, facebooks, mission, people, power, build, ...
# 393    [b, job, title, data, scientist, position, ove...
# 394    [babout, company, civis, analytics, technology...
# 395    [b, role, wework, datum, sit, center, business...
# 396    [babout, lark, worlds, large, ai, healthcare, ...
# 397    [b, zenreach, solve, major, problem, brickandm...
# 398    [b, position, description, walmart, voice, com...
# 399    [bby, trade, technology, company, ask, work, h...
# 400    [b, purpose, overall, relevance, organization,...
# 401    [b, dscout, dscout, core, people, nerds, empow...
# 402    [b, junior, data, scientist, big, data, entryl...
# 403    [babout, interested, work, humancentered, tech...
# 404    [b, air, products, inc, fortune, 500, manufact...
# 405    [b, data, scientist, want, opportunity, levera...
# 406    [b, job, description, data, scientist, interac...
# 407    [b, data, scientist, mine, analyze, complex, d...
# 408    [b, finlocker, lead, financial, datum, analyti...
# 409    [b, annual, sale, 15, billion, ecolab, ecl, gl...
# 410    [b, job, description, enterprise, data, soluti...
# 411    [b, description, chicago, il, il150sw, 150, s,...
# 412    [b, nike, supply, chain, expert, ensure, year,...
# 413    [b, principal, data, scientist, responsible, l...
# 414    [b, look, senior, data, scientist, market, ana...
# 415    [b, temporary, internship, marketing, data, sc...
# 416    [b, los, gatos, california, science, analytics...
# 417    [b, role, logic2020, look, secure, data, analy...
# 418    [b, contract, role, largely, operational, supp...
# 419    [b, bachelorxe2x80x99s, masterxe2x80x99s, degr...
# 420    [b, uber, ignite, opportunity, set, world, mot...
# 421    [b, us, want, fantastic, fun, startup, thatxe2...
# 422    [b, internship, uber, ignite, opportunity, set...
# 423    [b, 200000, 350000, year, million, people, yea...
# 424    [b, senior, data, scientist, job, description,...
# 425    [b, cerner, intelligence, new, innovative, org...
# Name: description, dtype: object

# %%
vect = nlp_utils.Scrubber()

# %%
vect.fit_transform(list(df["description"]))[:3]
# Out:
# [['b',
#   'job',
#   'requirements',
#   'learning',
#   'like',
#   'linear',
#   'logistic',
#   'regression',
#   'neural',
#   'random',
#   'decision',
#   'trees',
#   'handson',
#   '2',
#   'expert',
#   'level',
#   'code',
#   'write',
#   'functions',
#   'clean',
#   'efficient',
#   'role',
#   'exposure',
#   'package',
#   'like',
#   'numpy',
#   'pandas',
#   'etc',
#   'r',
#   'communicate',
#   'finding',
#   'technical',
#   'nontechnical',
#   'similar',
#   'programme',
#   'language',
#   'masters',
#   'degree',
#   'specific',
#   'field',
#   'apply'],
#  ['b',
#   'job',
#   'description',
#   '1',
#   'models',
#   'client',
#   'healthcare',
#   'journey',
#   'empower',
#   'improve',
#   'generation',
#   'applications',
#   'user',
#   'experiences',
#   'day',
#   'small',
#   'agile',
#   'design',
#   'develop',
#   'mobile',
#   'application',
#   'group',
#   'member',
#   'contribute',
#   'well',
#   'practice',
#   'guide',
#   'future',
#   'applications',
#   'effectively',
#   'collaborative',
#   'member',
#   'effectively',
#   'individual',
#   'responsible',
#   'meet',
#   'deliverable',
#   'time',
#   'high',
#   'quality',
#   'drive',
#   'implement',
#   'feature',
#   'mobile',
#   'applications',
#   'perform',
#   'test',
#   'write',
#   'test',
#   'case',
#   'cover',
#   'areas',
#   'identify',
#   'increase',
#   'code',
#   'quality',
#   'efficiency',
#   'well',
#   'develop',
#   'processes',
#   'code',
#   'design',
#   'necessary',
#   'innovate',
#   'maintain',
#   'great',
#   'quality',
#   'effectively',
#   'turn',
#   'design',
#   'document',
#   'creative',
#   'technical',
#   'skills',
#   'communicate',
#   'effectively',
#   'technical',
#   'environment',
#   'qualifications',
#   'look',
#   'masterxe2x80x99s',
#   'degree',
#   'computer',
#   'math',
#   'relate',
#   'field',
#   'computer',
#   'algorithm',
#   'design',
#   'complexity',
#   '1',
#   'realworld',
#   'develope',
#   'deploy',
#   'pipeline',
#   'key',
#   'accuracy',
#   'open',
#   'source',
#   'library',
#   'sql',
#   'proficient',
#   'write',
#   'test',
#   'familiar',
#   'automation',
#   'framework',
#   'cloud',
#   'infrastructure',
#   'aws',
#   'azure',
#   'plus',
#   'distribute',
#   'spark',
#   'plus',
#   'strong',
#   'write',
#   'oral',
#   'communication',
#   'skills',
#   'desire',
#   'agile',
#   'collaborative',
#   'innovative',
#   'flexible',
#   'environment',
#   'handson',
#   'motivate',
#   'selfstarter',
#   'solid',
#   'level',
#   'quickly',
#   'complex',
#   'challenge',
#   'technical',
#   'management',
#   'service',
#   'person',
#   'think',
#   'fast',
#   'spirit',
#   'fastpaced',
#   'environment',
#   'continuous',
#   'improvement',
#   'quality',
#   'high',
#   'challenge',
#   'growth',
#   'additional',
#   'information',
#   'important',
#   'culture',
#   'make',
#   'meaningful',
#   'impact',
#   'live',
#   'employees',
#   'member',
#   'customers',
#   'success',
#   'find',
#   'purpose',
#   'serve',
#   'making',
#   'difference',
#   'live',
#   'do',
#   'itxe2x80x99s',
#   'hard',
#   'right',
#   'thing',
#   'right',
#   'strong',
#   'together',
#   'wexe2x80x99re',
#   'colleague',
#   'embrace',
#   'different',
#   'background',
#   'enable',
#   'solve',
#   'creative',
#   'have',
#   'fun',
#   'way',
#   'results',
#   'motivate',
#   'us',
#   'hard',
#   'decision',
#   'need',
#   'wexe2x80x99re',
#   'healthcare',
#   'were',
#   'curious',
#   'act',
#   'big',
#   'risk',
#   'change',
#   'world',
#   'person',
#   'time',
#   'information',
#   'eeo'],
#  ['b',
#   'consult',
#   'responsible',
#   'analyze',
#   'large',
#   'complex',
#   'dataset',
#   'identify',
#   'meaningful',
#   'pattern',
#   'lead',
#   'actionable',
#   'recommendations',
#   'perform',
#   'test',
#   'validation',
#   'models',
#   'support',
#   'aspect',
#   'modeling',
#   'predictive',
#   'leverage',
#   'algorithms',
#   'position',
#   'combine',
#   'math',
#   'skills',
#   'research',
#   'advance',
#   'communication',
#   'presentation',
#   'skills',
#   'primary',
#   'job',
#   'location',
#   'option',
#   'available',
#   'qualifications',
#   'bachelors',
#   'ms',
#   'phd',
#   'relevant',
#   'field',
#   'computer',
#   'engineering',
#   'statistics',
#   'physics',
#   'applied',
#   'math',
#   'r',
#   'andor',
#   'prefer']]

# %%
vect = nlp_utils.Scrubber(no_below=50, no_above=100)

# %%
vect.fit_transform(list(df["description"]))[:2]
# Out:
# [['neural',
#   'handson',
#   'expert',
#   'package',
#   'finding',
#   'nontechnical',
#   'similar',
#   'masters',
#   'specific'],
#  ['description',
#   '1',
#   'healthcare',
#   'empower',
#   'generation',
#   'day',
#   'small',
#   'contribute',
#   'collaborative',
#   'meet',
#   'feature',
#   'efficiency',
#   'processes',
#   'creative',
#   'masterxe2x80x99s',
#   'math',
#   '1',
#   'deploy',
#   'pipeline',
#   'open',
#   'framework',
#   'infrastructure',
#   'aws',
#   'distribute',
#   'collaborative',
#   'flexible',
#   'handson',
#   'solid',
#   'quickly',
#   'fast',
#   'improvement',
#   'additional',
#   'culture',
#   'meaningful',
#   'live',
#   'customers',
#   'success',
#   'serve',
#   'live',
#   'right',
#   'thing',
#   'right',
#   'together',
#   'different',
#   'creative',
#   'results',
#   'healthcare',
#   'risk']]
